# %%
from requests import get
from requests.exceptions import RequestException
from contextlib import closing
from bs4 import BeautifulSoup
import pandas as pd
import os, sys
import re
import fire

# %%
#%%writefile ../pyscrap_url.py

def simple_get(url):
    """
    Attempts to get the content at `url` by making an HTTP GET request.
    If the content-type of response is some kind of HTML/XML, return the
    text content, otherwise return None.
    """
    try:
        with closing(get(url, stream=True)) as resp:
            if is_good_response(resp):
                return resp.content  #.encode(BeautifulSoup.original_encoding)
            else:
                return None

    except RequestException as e:
        log_error('Error during requests to {0} : {1}'.format(url, str(e)))
        return None


def is_good_response(resp):
    """
    Returns True if the response seems to be HTML, False otherwise.
    """
    content_type = resp.headers['Content-Type'].lower()
    return (resp.status_code == 200 
            and content_type is not None 
            and content_type.find('html') > -1)


def log_error(e):
    """
    It is always a good idea to log errors. 
    This function just prints them, but you can
    make it do anything.
    """
    print(e)
    
def get_elements(url, tag='',search={}, fname=None):
    """
    Downloads a page specified by the url parameter
    and returns a list of strings, one per tag element
    """
    
    if isinstance(url,str):
        response = simple_get(url)
    else:
        #if already it is a loaded html page
        response = url

    if response is not None:
        html = BeautifulSoup(response, 'html.parser')
        
        res = []
        if tag:    
            for li in html.select(tag):
                for name in li.text.split('\n'):
                    if len(name) > 0:
                        res.append(name.strip())
                       
                
        if search:
            soup = html            
            
            
            r = ''
            if 'find' in search.keys():
                print('finding',search['find'])
                soup = soup.find(**search['find'])
                r = soup

                
            if 'find_all' in search.keys():
                print('findaing all of',search['find_all'])
                r = soup.find_all(**search['find_all'])
   
            if r:
                for x in list(r):
                    if len(x) > 0:
                        res.extend(x)
            
        return res

    # Raise an exception if we failed to get any data from the url
    raise Exception('Error retrieving contents at {}'.format(url))    
    
    
if get_ipython().__class__.__name__ == '__main__':
    fire(get_tag_elements)

# %%
# scrapping names of journalists in Ghana
res = get_elements('http://www.businessghana.com/site/news/General/168602/Avance-Media-Announces-2018-Top-50-Ghanaian-Journalist-List', tag='li')

# %%
res
# res = re.findall(r"[\w]", res[0])
journ = []
journ_names = []
for i in res:
    journ.append(re.findall(r"[\w .]+", i))
for i in journ:
    if len(i) == 2:
        journ_names.append(i)
journ_names.pop(0)

# converting list into a dataframe
journ_df = pd.DataFrame(journ_names)
journ_df
# journ_df.to_csv("journ.csv")
# Out:
#                            0                         1
# 0      Abdul K. Malik Baako    The New Crusading Guide
# 1    Afia Adutwumwaa Morosa                   Peace FM
# 2               Afia Pokuaa                    Adom FM
# 3            Akosua Sarpong                        UTV
# 4            Akwasi Sarpong                        BBC
# 5             Ameyaw Debrah           AmeyawDebrah.com
# 6        Anas Aremeyaw Anas               Tiger Eye PI
# 7              Bernard Avle                    Citi FM
# 8             Bismark Brown                  Atinka TV
# 9         Bright Nana Amfom                        TV3
# 10         Dan Kweku Yeboah                   Peace FM
# 11              Daryl Kwawu                     Joy FM
# 12             Edward Kwabi                        TV3
# 13              Elvis Darko                 The Finder
# 14             Evans Mensah                     Joy FM
# 15            Fortune Alimi                Daily Guide
# 16            Francis Abban                   Starr FM
# 17               Gifty Anti               GDA Concepts
# 18            Israel Laryea                   Joy News
# 19         Jefferson Sackey        Presidency of Ghana
# 20            Juliet Bawuah                  Freelance
# 21              Kent Mensah          StarrFMOnline.com
# 22              Kofi Adomah                    Kofi TV
# 23             Komla Klutse                        TV3
# 24       Kwabena K. Boateng                   GhanaWeb
# 25           Kwabena Yeboah                        GTV
# 26          Kwame Sefa Kayi                   Peace FM
# 27             Kweku Temeng                   GHOne TV
# 28              Kwesi Pratt      The Insight Newspaper
# 29       Mabel Aku Banesseh              Daily Graphic
# 30     Manasseh Azure Awuni                     Joy FM
# 31        Michael Oti Adjei                        TV3
# 32         Nana Aba Anamoah                   GHOne TV
# 33   Nana Yaw Ampofo Ankrah                   Kwese TV
# 34  Omanhene Kwabena Asante                    Adom TV
# 35        Patrice Amegashie                  TV Africa
# 36    Patrick Osei Agyemang                    Adom TV
# 37        Paul Adom Otchere                   Metro TV
# 38               Peace Hyde              Forbes Africa
# 39  Ridwan Karim Dini Osman                   GHOne TV
# 40            Saddick Adams                  Atinka FM
# 41  Selikem Apaloo Acolatse                        GTV
# 42       Seth Kwame Boateng                     Joy FM
# 43    Thomas Naadi Bitlegma                        BBC
# 44        Umaru Sanda Amadu                    Citi FM
# 45         Vivian Kai Lokko                    Citi FM
