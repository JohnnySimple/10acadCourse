# %%
import pandas as pd

# %%
# !pip install xlrd
# Out:
# ...
# WARNING: You are using pip version 19.3.1; however, version 20.1.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
data = pd.read_excel('Week2_challenge_data_source.xlsx', sheetname=None)

# %%
# data = data['Sheet1']
df = pd.DataFrame(data)

# %%
# len(df) - df.count()  # counting the number of null values

# %%
# df.to_csv('challenge2-data.csv')

# %%
df.T
# Out:
#                                                               0       \
# Bearer Id                                       13114483460844900352
# Start                                            2019-04-04 12:01:18
# Start ms                                                         770
# End                                              2019-04-25 14:35:31
# End ms                                                           662
# Dur. (ms)                                                1.82365e+06
# IMSI                                                     2.08201e+14
# MSISDN/Number                                             3.3665e+10
# IMEI                                                     3.55212e+13
# Last Location Name                                  9164566995485190
# Avg RTT DL (ms)                                                   42
# Avg RTT UL (ms)                                                    5
# Avg Bearer TP DL (kbps)                                           23
# ...
